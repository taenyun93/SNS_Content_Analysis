# %% [markdown]
# # Facebook & Insta Chi Square

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", 300)
pd.set_option("display.max_rows", 200)

# %%
fpath = os.path.join('data')
df_sns_clean = pd.read_csv(os.path.join(fpath,'df_sns_cleaned.csv'),encoding = 'utf-8')

# %% [markdown]
# ### 3Model

# %%
from scipy import stats
import researchpy as rp

# %%
def t_test_sns(df,dv):
    data = df.copy()
    
    facebook = data[data['X1SNS'] == 1]
    insta = data[data['X1SNS'] == 2]
    
    facebook_dv = facebook[dv]
    insta_dv = insta[dv]
    
    result = rp.ttest(facebook_dv,insta_dv,group1_name = 'Facebook',group2_name = 'Instagram')
    
    return result

# %%
def chi_sns(df,dv_idx,cat_dict = {1:'Y',0:'N'}):
    data = df.copy()
    
    sns_dict = {1:'Facebook',2:'instagram'}
    for k,v in sns_dict.items():
        
        data.loc[data['X1SNS']==k,['X1SNS']] = v
        
    
    yn_dict = cat_dict
    for k,v in yn_dict.items():
        
        data.loc[data[dv_idx]==k,[dv_idx]] = v
    
    iv = data['X1SNS']
    dv = data[dv_idx]
    
    #facebook['1SNS'] = 'facebook'
    #insta['1SNS'] = 'insta'
    
    
    result = rp.crosstab(iv, dv, test = 'chi-square', margins= True, correction = None, exact = False, expected_freqs= False)
    
    return result

# %%
def chi_iter_sns(df,dv_idx,cat_dict = None):
    data = df.copy()
    
    
    
    if cat_dict:
        
        test_dict = cat_dict
    
    
        for k,v in test_dict.items():
            data.loc[data[dv_idx]== k,dv_idx] = v

    
    sns_dict = {1:'Facebook',2:'instagram'}
    for k,v in sns_dict.items():
        
        data.loc[data['X1SNS']==k,['X1SNS']] = v
        
    iv = data['X1SNS']
    
        
    dv_dummies = pd.get_dummies(data[dv_idx])
    
    #facebook['1SNS'] = 'facebook'
    #insta['1SNS'] = 'insta'
    
    
    for dv_idx in dv_dummies:
        dv = dv_dummies[dv_idx]
        result = rp.crosstab(iv, dv, test = 'chi-square', margins= True, correction = None, exact = False, expected_freqs= False)
        
        
        
        p = result[1].iloc[1,1]
        score = importance(p)
        
        print('[%s]'%dv_idx)
        print(result[0],'\n')
        print(result[1],'\n')
        print('Importance: %s\n'%score)

# %%
def importance(p):
    score = 'X'
    if p <= 0.001:
        score = '***'
    elif p <= 0.01:
        score = '**'
    elif p <= 0.05:
        score = '*'
    
    return score
   # result[1].iloc[1,1]

# %%
col = 'X3model'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)


df_model = df_sns_clean[df_sns_clean['X3model'] == 1]
chi_col = ['X32face', 'X33body']
for col in chi_col:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    p = result[1].iloc[1,1]
    print(result[0],'\n')
    print(result[1],'\n')
    score = importance(p)
    print('Importance: %s\n'%score)
    
    
#result[1].iloc[1,1]
# Out:
# [X3model]
#           X3model
#                 N     Y   All
# X1SNS
# Facebook      312   688  1000
# instagram     337   660   997
# All           649  1348  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.5401
# 1                    p-value =    0.2146
# 2               Cramer's phi =    0.0278
#
# Importance: X
#
# [X32face]
#           X32face
#                 N     Y   All
# X1SNS
# Facebook      140   548   688
# instagram     150   510   660
# All           290  1058  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.1286
# 1                    p-value =    0.2881
# 2               Cramer's phi =    0.0289
#
# Importance: X
#
# [X33body]
#           X33body
#               2.0    Y   All
# X1SNS
# Facebook      395  293   688
# instagram     358  301   659
# All           753  594  1347
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.3021
# 1                    p-value =    0.2538
# 2               Cramer's phi =    0.0311
#
# Importance: X

# %%
result = t_test_sns(df_model,'X31number')
p = result[1].iloc[3,1]
score = importance(p)

print('[X31number]')
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X31number]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   688.0  1.861919  2.848908  0.108614   1.648664  2.075173
# 1  Instagram   660.0  2.022727  3.016057  0.117400   1.792204  2.253250
# 2   combined  1348.0  1.940653  2.931949  0.079857   1.783996  2.097310
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.1608
# 1                            Degrees of freedom =   1346.0000
# 2                                             t =     -1.0066
# 3                         Two side test p value =      0.3143
# 4  Mean of Facebook > mean of Instagram p value =      0.1571
# 5  Mean of Facebook < mean of Instagram p value =      0.8429
# 6                                     Cohen's d =     -0.0548
# 7                                     Hedge's g =     -0.0548
# 8                                 Glass's delta =     -0.0564
# 9                                             r =      0.0274
#
# Importance: X

# %%
position_col_name = 'X34modelposition_'
df_position = df_model

print("[[%s]]\n\n"%(position_col_name.replace("_","")))
position_col = [position_col_name in s for s  in df_position.columns]
position_columns = df_model.loc[:,position_col].columns

for col in position_columns:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    print(result[0],'\n')
    print(result[1],'\n')
    
    p = result[1].iloc[1,1]
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[X34modelposition]]
#
#
# [X34modelposition_1]
#           X34modelposition_1
#                            N    Y   All
# X1SNS
# Facebook                 306  382   688
# instagram                288  372   660
# All                      594  754  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0965
# 1                    p-value =    0.7560
# 2               Cramer's phi =    0.0085
#
# Importance: X
#
# [X34modelposition_2]
#           X34modelposition_2
#                            N     Y   All
# X1SNS
# Facebook                  78   610   688
# instagram                 59   601   660
# All                      137  1211  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.1212
# 1                    p-value =    0.1453
# 2               Cramer's phi =    0.0397
#
# Importance: X
#
# [X34modelposition_3]
#           X34modelposition_3
#                            N    Y   All
# X1SNS
# Facebook                 287  401   688
# instagram                238  422   660
# All                      525  823  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    4.5295
# 1                    p-value =    0.0333
# 2               Cramer's phi =    0.0580
#
# Importance: *
#
# [X34modelposition_4]
#           X34modelposition_4
#                            N     Y   All
# X1SNS
# Facebook                 190   498   688
# instagram                155   505   660
# All                      345  1003  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    3.0193
# 1                    p-value =    0.0823
# 2               Cramer's phi =    0.0473
#
# Importance: X
#
# [X34modelposition_5]
#           X34modelposition_5
#                            N     Y   All
# X1SNS
# Facebook                  25   663   688
# instagram                 21   639   660
# All                       46  1302  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.2087
# 1                    p-value =    0.6478
# 2               Cramer's phi =    0.0124
#
# Importance: X
#
# [X34modelposition_6]
#           X34modelposition_6
#                            N     Y   All
# X1SNS
# Facebook                 179   509   688
# instagram                139   521   660
# All                      318  1030  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    4.5916
# 1                    p-value =    0.0321
# 2               Cramer's phi =    0.0584
#
# Importance: *
#
# [X34modelposition_7]
#           X34modelposition_7
#                            N    Y   All
# X1SNS
# Facebook                 218  470   688
# instagram                196  464   660
# All                      414  934  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.6263
# 1                    p-value =    0.4287
# 2               Cramer's phi =    0.0216
#
# Importance: X
#
# [X34modelposition_8]
#           X34modelposition_8
#                            N     Y   All
# X1SNS
# Facebook                  44   644   688
# instagram                 45   615   660
# All                       89  1259  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0977
# 1                    p-value =    0.7546
# 2               Cramer's phi =    0.0085
#
# Importance: X
#
# [X34modelposition_9]
#           X34modelposition_9
#                            N    Y   All
# X1SNS
# Facebook                 189  499   688
# instagram                185  475   660
# All                      374  974  1348
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0526
# 1                    p-value =    0.8186
# 2               Cramer's phi =    0.0062
#
# Importance: X

# %% [markdown]
# ### 4background

# %%
chi_iter_sns(df_sns_clean,'X4background',{1:'wall',2:'indoor',3:'outdoor',4:'others'})
# Out:
# [indoor]
#           indoor
#                0    1   All
# X1SNS
# Facebook     824  176  1000
# instagram    880  117   997
# All         1704  293  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   13.7164
# 1                    p-value =    0.0002
# 2               Cramer's phi =    0.0829
#
# Importance: ***
#
# [others]
#           others
#                0   1   All
# X1SNS
# Facebook     944  56  1000
# instagram    956  41   997
# All         1900  97  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.3909
# 1                    p-value =    0.1220
# 2               Cramer's phi =    0.0346
#
# Importance: X
#
# [outdoor]
#           outdoor
#                 0    1   All
# X1SNS
# Facebook      675  325  1000
# instagram     765  232   997
# All          1440  557  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   21.1484
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.1029
#
# Importance: ***
#
# [wall]
#           wall
#              0     1   All
# X1SNS
# Facebook   557   443  1000
# instagram  390   607   997
# All        947  1050  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   55.0607
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.1660
#
# Importance: ***

# %% [markdown]
# ### 5Text

# %%
col = 'X5text'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X5text]
#           X5text
#                N    Y   All
# X1SNS
# Facebook     839  161  1000
# instagram    884  112   996
# All         1723  273  1996
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    9.9622
# 1                    p-value =    0.0016
# 2               Cramer's phi =    0.0706
#
# Importance: **

# %%
df_text = df_sns_clean[df_sns_clean['X5text'] == 1]

# %%
#result = t_test_sns(df_test,'31number')


ttest_col = ['X51words']
for col in ttest_col:
    print('[%s]'%col)
    result = t_test_sns(df_text,col)
    p = result[1].iloc[3,1]
    print(result[0],'\n')
    print(result[1],'\n')
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [X51words]
#     Variable      N      Mean         SD        SE  95% Conf.  Interval
# 0   Facebook  161.0  6.416149   8.595463  0.677417   5.078316  7.753982
# 1  Instagram  112.0  6.160714  13.061568  1.234202   3.715060  8.606368
# 2   combined  273.0  6.311355  10.634733  0.643643   5.044199  7.578511
#
#                                 Independent t-test   results
# 0             Difference (Facebook - Instagram) =     0.2554
# 1                            Degrees of freedom =   271.0000
# 2                                             t =     0.1949
# 3                         Two side test p value =     0.8456
# 4  Mean of Facebook > mean of Instagram p value =     0.5772
# 5  Mean of Facebook < mean of Instagram p value =     0.4228
# 6                                     Cohen's d =     0.0240
# 7                                     Hedge's g =     0.0239
# 8                                 Glass's delta =     0.0297
# 9                                             r =     0.0118
#
# Importance: X

# %%
col = 'X54promotingmessa'

result = chi_sns(df_text,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X54promotingmessa]
#           X54promotingmessa
#                           N   Y  All
# X1SNS
# Facebook                141  20  161
# instagram               103   9  112
# All                     244  29  273
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.3387
# 1                    p-value =    0.2473
# 2               Cramer's phi =    0.0700
#
# Importance: X

# %%
position_col_name = 'X53textposition_'
df_position = df_text

print("[[%s]]\n\n"%(position_col_name.replace("_","")))
position_col = [position_col_name in s for s  in df_position.columns]
position_columns = df_model.loc[:,position_col].columns

for col in position_columns:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    print(result[0],'\n')
    print(result[1],'\n')
    p = result[1].iloc[1,1]
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[X53textposition]]
#
#
# [X53textposition_1]
#           X53textposition_1
#                           N   Y  All
# X1SNS
# Facebook                 76  17   93
# instagram                40  11   51
# All                     116  28  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.2275
# 1                    p-value =    0.6334
# 2               Cramer's phi =    0.0397
#
# Importance: X
#
# [X53textposition_2]
#           X53textposition_2
#                           N   Y  All
# X1SNS
# Facebook                 72  21   93
# instagram                32  19   51
# All                     104  40  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    3.5354
# 1                    p-value =    0.0601
# 2               Cramer's phi =    0.1567
#
# Importance: X
#
# [X53textposition_3]
#           X53textposition_3
#                           N   Y  All
# X1SNS
# Facebook                 77  16   93
# instagram                37  14   51
# All                     114  30  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.0968
# 1                    p-value =    0.1476
# 2               Cramer's phi =    0.1207
#
# Importance: X
#
# [X53textposition_4]
#           X53textposition_4
#                           N   Y  All
# X1SNS
# Facebook                 43  50   93
# instagram                29  22   51
# All                      72  72  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.4877
# 1                    p-value =    0.2226
# 2               Cramer's phi =    0.1016
#
# Importance: X
#
# [X53textposition_5]
#           X53textposition_5
#                           N   Y  All
# X1SNS
# Facebook                 26  67   93
# instagram                23  28   51
# All                      49  95  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    4.3109
# 1                    p-value =    0.0379
# 2               Cramer's phi =    0.1730
#
# Importance: *
#
# [X53textposition_6]
#           X53textposition_6
#                           N   Y  All
# X1SNS
# Facebook                 49  44   93
# instagram                29  22   51
# All                      78  66  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.2312
# 1                    p-value =    0.6306
# 2               Cramer's phi =    0.0401
#
# Importance: X
#
# [X53textposition_7]
#           X53textposition_7
#                           N   Y  All
# X1SNS
# Facebook                 67  26   93
# instagram                31  20   51
# All                      98  46  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.9205
# 1                    p-value =    0.1658
# 2               Cramer's phi =    0.1155
#
# Importance: X
#
# [X53textposition_8]
#           X53textposition_8
#                           N   Y  All
# X1SNS
# Facebook                 56  37   93
# instagram                31  20   51
# All                      87  57  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0045
# 1                    p-value =    0.9467
# 2               Cramer's phi =    0.0056
#
# Importance: X
#
# [X53textposition_9]
#           X53textposition_9
#                           N   Y  All
# X1SNS
# Facebook                 70  23   93
# instagram                35  16   51
# All                     105  39  144
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.7357
# 1                    p-value =    0.3911
# 2               Cramer's phi =    0.0715
#
# Importance: X

# %% [markdown]
# ### 6Brandname

# %%
col = 'X6brandname'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X6brandname]
#           X6brandname
#                     N    Y   All
# X1SNS
# Facebook          812  188  1000
# instagram         811  186   997
# All              1623  374  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0068
# 1                    p-value =    0.9343
# 2               Cramer's phi =    0.0018
#
# Importance: X

# %%
df_brand = df_sns_clean[(df_sns_clean['X6brandname'] == 1)]

cols = ['X61brandexpose','X65partofprod']
for col in cols: 
    result = chi_sns(df_brand,col)
    p = result[1].iloc[1,1]
    score = importance(p)

    print('[%s]'%col)
    print(result[0],'\n')
    print(result[1],'\n')
    print('Importance: %s\n'%score)
    
col = 'X64brandvisib'
result = chi_sns(df_brand,col,{0:'low',1:'high'})
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')

print('Importance: %s\n'%score)
# Out:
# [X61brandexpose]
#           X61brandexpose
#                        N    Y  All
# X1SNS
# Facebook              11  177  188
# instagram             25  161  186
# All                   36  338  374
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    6.1913
# 1                    p-value =    0.0128
# 2               Cramer's phi =    0.1287
#
# Importance: *
#
# [X65partofprod]
#           X65partofprod
#                       N    Y  All
# X1SNS
# Facebook             91   97  188
# instagram            34  152  186
# All                 125  249  374
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   38.1310
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.3193
#
# Importance: ***
#
# [X64brandvisib]
#           X64brandvisib
#                    high  low  All
# X1SNS
# Facebook             94   94  188
# instagram            95   91  186
# All                 189  185  374
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0432
# 1                    p-value =    0.8353
# 2               Cramer's phi =    0.0108
#
# Importance: X

# %%
position_col_name = 'X63brandposition_'
df_position = df_brand

print("[[%s]]\n\n"%(position_col_name.replace("_","")))
position_col = [position_col_name in s for s  in df_position.columns]
position_columns = df_model.loc[:,position_col].columns

for col in position_columns:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    p = result[1].iloc[1,1]
    print(result[0],'\n')
    print(result[1],'\n')
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[X63brandposition]]
#
#
# [X63brandposition_1]
#           X63brandposition_1
#                            N   Y  All
# X1SNS
# Facebook                  70   8   78
# instagram                 58  11   69
# All                      128  19  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.0516
# 1                    p-value =    0.3051
# 2               Cramer's phi =    0.0846
#
# Importance: X
#
# [X63brandposition_2]
#           X63brandposition_2
#                            N   Y  All
# X1SNS
# Facebook                  67  11   78
# instagram                 55  14   69
# All                      122  25  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.9930
# 1                    p-value =    0.3190
# 2               Cramer's phi =    0.0822
#
# Importance: X
#
# [X63brandposition_3]
#           X63brandposition_3
#                            N   Y  All
# X1SNS
# Facebook                  76   2   78
# instagram                 61   8   69
# All                      137  10  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =     4.709
# 1                    p-value =     0.030
# 2               Cramer's phi =     0.179
#
# Importance: *
#
# [X63brandposition_4]
#           X63brandposition_4
#                            N   Y  All
# X1SNS
# Facebook                  66  12   78
# instagram                 51  18   69
# All                      117  30  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.5817
# 1                    p-value =    0.1081
# 2               Cramer's phi =    0.1325
#
# Importance: X
#
# [X63brandposition_5]
#           X63brandposition_5
#                            N   Y  All
# X1SNS
# Facebook                  45  33   78
# instagram                 43  26   69
# All                       88  59  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.3262
# 1                    p-value =    0.5679
# 2               Cramer's phi =    0.0471
#
# Importance: X
#
# [X63brandposition_6]
#           X63brandposition_6
#                            N   Y  All
# X1SNS
# Facebook                  60  18   78
# instagram                 54  15   69
# All                      114  33  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0376
# 1                    p-value =    0.8462
# 2               Cramer's phi =    0.0160
#
# Importance: X
#
# [X63brandposition_7]
#           X63brandposition_7
#                            N   Y  All
# X1SNS
# Facebook                  72   6   78
# instagram                 58  11   69
# All                      130  17  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.4364
# 1                    p-value =    0.1185
# 2               Cramer's phi =    0.1287
#
# Importance: X
#
# [X63brandposition_8]
#           X63brandposition_8
#                            N   Y  All
# X1SNS
# Facebook                  62  16   78
# instagram                 54  15   69
# All                      116  31  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0331
# 1                    p-value =    0.8557
# 2               Cramer's phi =    0.0150
#
# Importance: X
#
# [X63brandposition_9]
#           X63brandposition_9
#                            N   Y  All
# X1SNS
# Facebook                  64  14   78
# instagram                 60   9   69
# All                      124  23  147
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.6675
# 1                    p-value =    0.4139
# 2               Cramer's phi =    0.0674
#
# Importance: X

# %%
position_col_name = 'X66whproduct_'
df_position = df_brand

print("[[%s]]\n\n"%(position_col_name.replace("_","")))
position_col = [position_col_name in s for s  in df_position.columns]
position_columns = df_model.loc[:,position_col].columns

for col in position_columns:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    print(result[0],'\n')
    print(result[1],'\n')
    p = result[1].iloc[1,1]
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[X66whproduct]]
#
#
# [X66whproduct_accessories]
#           X66whproduct_accessories
#                                  N  Y All
# X1SNS
# Facebook                        43  1  44
# instagram                       53  0  53
# All                             96  1  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.2171
# 1                    p-value =    0.2699
# 2               Cramer's phi =    0.1120
#
# Importance: X
#
# [X66whproduct_bag]
#           X66whproduct_bag
#                          N  Y All
# X1SNS
# Facebook                39  5  44
# instagram               51  2  53
# All                     90  7  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.0685
# 1                    p-value =    0.1504
# 2               Cramer's phi =    0.1460
#
# Importance: X
#
# [X66whproduct_clothes_bottom]
#           X66whproduct_clothes_bottom
#                                     N  Y All
# X1SNS
# Facebook                           41  3  44
# instagram                          47  6  53
# All                                88  9  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.5790
# 1                    p-value =    0.4467
# 2               Cramer's phi =    0.0773
#
# Importance: X
#
# [X66whproduct_clothes_top]
#           X66whproduct_clothes_top
#                                  N   Y All
# X1SNS
# Facebook                        24  20  44
# instagram                       26  27  53
# All                             50  47  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.2900
# 1                    p-value =    0.5902
# 2               Cramer's phi =    0.0547
#
# Importance: X
#
# [X66whproduct_cosmetics]
#           X66whproduct_cosmetics
#                                N  Y All
# X1SNS
# Facebook                      43  1  44
# instagram                     52  1  53
# All                           95  2  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0177
# 1                    p-value =    0.8941
# 2               Cramer's phi =    0.0135
#
# Importance: X
#
# [X66whproduct_hat]
#           X66whproduct_hat
#                          N  Y All
# X1SNS
# Facebook                43  1  44
# instagram               49  4  53
# All                     92  5  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.3680
# 1                    p-value =    0.2422
# 2               Cramer's phi =    0.1188
#
# Importance: X
#
# [X66whproduct_others]
#           X66whproduct_others
#                             N  Y All
# X1SNS
# Facebook                   41  3  44
# instagram                  52  1  53
# All                        93  4  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.4788
# 1                    p-value =    0.2240
# 2               Cramer's phi =    0.1235
#
# Importance: X
#
# [X66whproduct_shoes]
#           X66whproduct_shoes
#                            N   Y All
# X1SNS
# Facebook                  30  14  44
# instagram                 34  19  53
# All                       64  33  97
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.1740
# 1                    p-value =    0.6766
# 2               Cramer's phi =    0.0424
#
# Importance: X

# %% [markdown]
# ### 7Brandlogo

# %%
col = 'X7logo'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X7logo]
#           X7logo
#                N    Y   All
# X1SNS
# Facebook     623  377  1000
# instagram    591  406   997
# All         1214  783  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.9131
# 1                    p-value =    0.1666
# 2               Cramer's phi =    0.0310
#
# Importance: X

# %%
df_logo = df_sns_clean[(df_sns_clean['X7logo'] == 1)]

##
col = 'X71logoexposure'
result = chi_sns(df_logo,col,{1:'whole',0:'part'})
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)

##
col = 'X75logovisib'
result = chi_sns(df_logo,col,{0:'low',1:'high'})
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)

##
col = 'X76logopartofprod'
result = chi_sns(df_logo,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X71logoexposure]
#           X71logoexposure
#                      part whole  All
# X1SNS
# Facebook               14   362  376
# instagram              30   376  406
# All                    44   738  782
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    4.9401
# 1                    p-value =    0.0262
# 2               Cramer's phi =    0.0795
#
# Importance: *
#
# [X75logovisib]
#           X75logovisib
#                   high  low  All
# X1SNS
# Facebook           192  185  377
# instagram          247  159  406
# All                439  344  783
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    7.7924
# 1                    p-value =    0.0052
# 2               Cramer's phi =    0.0998
#
# Importance: **
#
# [X76logopartofprod]
#           X76logopartofprod
#                           N    Y  All
# X1SNS
# Facebook                107  270  377
# instagram                46  360  406
# All                     153  630  783
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   36.1529
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.2149
#
# Importance: ***

# %%
chi_iter_sns(df_logo,'X74logotype',{1:'Image',2:'Text',3:'Both'})
# Out:
# [Both]
#           Both
#              0    1  All
# X1SNS
# Facebook   272  105  377
# instagram  273  133  406
# All        545  238  783
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.2249
# 1                    p-value =    0.1358
# 2               Cramer's phi =    0.0533
#
# Importance: X
#
# [Image]
#           Image
#               0    1  All
# X1SNS
# Facebook    167  210  377
# instagram   173  233  406
# All         340  443  783
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.2262
# 1                    p-value =    0.6343
# 2               Cramer's phi =    0.0170
#
# Importance: X
#
# [Text]
#           Text
#              0    1  All
# X1SNS
# Facebook   315   62  377
# instagram  366   40  406
# All        681  102  783
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    7.5007
# 1                    p-value =    0.0062
# 2               Cramer's phi =    0.0979
#
# Importance: **

# %%
position_col_name = 'X73logoposition_'
df_position = df_logo

print("[[%s]]\n\n"%(position_col_name.replace("_","")))
position_col = [position_col_name in s for s  in df_position.columns]
position_columns = df_model.loc[:,position_col].columns

for col in position_columns:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    print(result[0],'\n')
    print(result[1],'\n')
    p = result[1].iloc[1,1]
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[X73logoposition]]
#
#
# [X73logoposition_1]
#           X73logoposition_1
#                           N   Y  All
# X1SNS
# Facebook                191  29  220
# instagram               194  20  214
# All                     385  49  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.5938
# 1                    p-value =    0.2068
# 2               Cramer's phi =    0.0606
#
# Importance: X
#
# [X73logoposition_2]
#           X73logoposition_2
#                           N   Y  All
# X1SNS
# Facebook                173  47  220
# instagram               167  47  214
# All                     340  94  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0229
# 1                    p-value =    0.8796
# 2               Cramer's phi =    0.0073
#
# Importance: X
#
# [X73logoposition_3]
#           X73logoposition_3
#                           N   Y  All
# X1SNS
# Facebook                191  29  220
# instagram               192  22  214
# All                     383  51  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.8806
# 1                    p-value =    0.3480
# 2               Cramer's phi =    0.0450
#
# Importance: X
#
# [X73logoposition_4]
#           X73logoposition_4
#                           N   Y  All
# X1SNS
# Facebook                175  45  220
# instagram               170  44  214
# All                     345  89  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0008
# 1                    p-value =    0.9781
# 2               Cramer's phi =    0.0013
#
# Importance: X
#
# [X73logoposition_5]
#           X73logoposition_5
#                           N    Y  All
# X1SNS
# Facebook                123   97  220
# instagram               106  108  214
# All                     229  205  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.7696
# 1                    p-value =    0.1834
# 2               Cramer's phi =    0.0639
#
# Importance: X
#
# [X73logoposition_6]
#           X73logoposition_6
#                           N    Y  All
# X1SNS
# Facebook                165   55  220
# instagram               161   53  214
# All                     326  108  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0032
# 1                    p-value =    0.9551
# 2               Cramer's phi =    0.0027
#
# Importance: X
#
# [X73logoposition_7]
#           X73logoposition_7
#                           N   Y  All
# X1SNS
# Facebook                168  52  220
# instagram               172  42  214
# All                     340  94  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.0281
# 1                    p-value =    0.3106
# 2               Cramer's phi =    0.0487
#
# Importance: X
#
# [X73logoposition_8]
#           X73logoposition_8
#                           N    Y  All
# X1SNS
# Facebook                139   81  220
# instagram               127   87  214
# All                     266  168  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.6728
# 1                    p-value =    0.4121
# 2               Cramer's phi =    0.0394
#
# Importance: X
#
# [X73logoposition_9]
#           X73logoposition_9
#                           N    Y  All
# X1SNS
# Facebook                165   55  220
# instagram               168   46  214
# All                     333  101  434
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.7462
# 1                    p-value =    0.3877
# 2               Cramer's phi =    0.0415
#
# Importance: X

# %% [markdown]
# ### 8Product Exposure

# %%
pd.DataFrame(df_sns_clean[(df_sns_clean['X8product'] == 1)].isna().sum()).T
# Out:
#    BrandID  BrandCategory  PhotoID  PostURL  PhotoURL  PostDate  PostTime  \
# 0        0              0        0        0         2         0         0
#
#    DownloadDate  Type  type_video  Like  LikeAlbum  Comments  Comments_album  \
# 0             0     0           0     4       1610       933            1614
#
#    NumHashtags  Content  ContentWithoutLink  X1SNS  X2brand  X3model  \
# 0            3       34                  37      0        0        0
#
#    X31number  X32face  X33body  X34modelposition  X4background  X5text  \
# 0        452      452      453               452             0       1
#
#    X51words   X52  X53textposition  X54promotingmessa  X6brandname  \
# 0      1571  1761             1571               1571            0
#
#    X61brandexpose   X62  X63brandposition  X64brandvisib  X65partofprod  \
# 0            1441  1761              1441           1441           1441
#
#    X66whproduct  X7logo  X71logoexposure   X72  X73logoposition  X74logotype  \
# 0          1511       0             1058  1760             1057         1057
#
#    X75logovisib  X76logopartofprod  X8product  X81productexpose   X82  \
# 0          1057               1056          0                 0  1761
#
#    X83productposition    X9  X10angle   X11  X12hashtag  X12_1number  \
# 0                   0  1761         0  1761           0            0
#
#    X12_2_1content  X12_2_2  X12_2_3  X12_2_4  X12_2_5  X12_2_6  X13text  \
# 0               0        0        0        0        0        0        0
#
#    X13_1  X13_2promo  X13_2promo_wo_kor  X13_3link  XBrandCategory_SPA  \
# 0      0          39                 66         37                   0
#
#    XBrandCategory_casual  XBrandCategory_luxuries  XBrandCategory_sport  \
# 0                      0                        0                     0
#
#    X34modelposition_1  X34modelposition_2  X34modelposition_3  \
# 0                 452                 452                 452
#
#    X34modelposition_4  X34modelposition_5  X34modelposition_6  \
# 0                 452                 452                 452
#
#    X34modelposition_7  X34modelposition_8  X34modelposition_9  \
# 0                 452                 452                 452
#
#    X4background_indoor  X4background_others  X4background_outdoor  \
# 0                    0                    0                     0
#
#    X4background_wall  X53textposition_1  X53textposition_2  X53textposition_3  \
# 0                  0               1571               1571               1571
#
#    X53textposition_4  X53textposition_5  X53textposition_6  X53textposition_7  \
# 0               1571               1571               1571               1571
#
#    X53textposition_8  X53textposition_9  X63brandposition_1  \
# 0               1571               1571                1441
#
#    X63brandposition_2  X63brandposition_3  X63brandposition_4  \
# 0                1441                1441                1441
#
#    X63brandposition_5  X63brandposition_6  X63brandposition_7  \
# 0                1441                1441                1441
#
#    X63brandposition_8  X63brandposition_9  X66whproduct_accessories  \
# 0                1441                1441                      1511
#
#    X66whproduct_bag  X66whproduct_clothes_bottom  X66whproduct_clothes_top  \
# 0              1511                         1511                      1511
#
#    X66whproduct_cosmetics  X66whproduct_hat  X66whproduct_others  \
# 0                    1511              1511                 1511
#
#    X66whproduct_shoes  X73logoposition_1  X73logoposition_2  \
# 0                1511               1057               1057
#
#    X73logoposition_3  X73logoposition_4  X73logoposition_5  X73logoposition_6  \
# 0               1057               1057               1057               1057
#
#    X73logoposition_7  X73logoposition_8  X73logoposition_9  X74logotype_both  \
# 0               1057               1057               1057              1057
#
#    X74logotype_image  X74logotype_text  X83productposition_1  \
# 0               1057              1057                     0
#
#    X83productposition_2  X83productposition_3  X83productposition_4  \
# 0                     0                     0                     0
#
#    X83productposition_5  X83productposition_6  X83productposition_7  \
# 0                     0                     0                     0
#
#    X83productposition_8  X83productposition_9  X10angle_extreme_high  \
# 0                     0                     0                      0
#
#    X10angle_eye  X10angle_high  X10angle_low  X10angle_other
# 0             0              0             0               0

# %%
col = 'X8product'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)

df_product = df_sns_clean[(df_sns_clean['X8product'] == 1)]

col = 'X81productexpose'
result = chi_sns(df_product,col,{1:'Whole',0:'Part'})
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X8product]
#           X8product
#                   N     Y   All
# X1SNS
# Facebook        152   848  1000
# instagram        84   913   997
# All             236  1761  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   21.9880
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.1049
#
# Importance: ***
#
# [X81productexpose]
#           X81productexpose
#                       Part Whole   All
# X1SNS
# Facebook               154   694   848
# instagram              207   706   913
# All                    361  1400  1761
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    5.4923
# 1                    p-value =    0.0191
# 2               Cramer's phi =    0.0558
#
# Importance: *

# %%
position_col_name = 'X83productposition_'
df_position = df_product

print("[[%s]]\n\n"%(position_col_name.replace("_","")))
position_col = [position_col_name in s for s  in df_position.columns]
position_columns = df_model.loc[:,position_col].columns

for col in position_columns:
    print('[%s]'%col)
    result = chi_sns(df_model,col)
    print(result[0],'\n')
    print(result[1],'\n')
    p = result[1].iloc[1,1]
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[X83productposition]]
#
#
# [X83productposition_1]
#           X83productposition_1
#                              N    Y   All
# X1SNS
# Facebook                   371  288   659
# instagram                  399  250   649
# All                        770  538  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    3.6260
# 1                    p-value =    0.0569
# 2               Cramer's phi =    0.0527
#
# Importance: X
#
# [X83productposition_2]
#           X83productposition_2
#                              N    Y   All
# X1SNS
# Facebook                   200  459   659
# instagram                  222  427   649
# All                        422  886  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.2264
# 1                    p-value =    0.1357
# 2               Cramer's phi =    0.0413
#
# Importance: X
#
# [X83productposition_3]
#           X83productposition_3
#                              N    Y   All
# X1SNS
# Facebook                   361  298   659
# instagram                  362  287   649
# All                        723  585  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.1318
# 1                    p-value =    0.7166
# 2               Cramer's phi =    0.0100
#
# Importance: X
#
# [X83productposition_4]
#           X83productposition_4
#                              N    Y   All
# X1SNS
# Facebook                   222  437   659
# instagram                  198  451   649
# All                        420  888  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.5158
# 1                    p-value =    0.2183
# 2               Cramer's phi =    0.0340
#
# Importance: X
#
# [X83productposition_5]
#           X83productposition_5
#                              N     Y   All
# X1SNS
# Facebook                    57   602   659
# instagram                   50   599   649
# All                        107  1201  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.3890
# 1                    p-value =    0.5328
# 2               Cramer's phi =    0.0172
#
# Importance: X
#
# [X83productposition_6]
#           X83productposition_6
#                              N    Y   All
# X1SNS
# Facebook                   200  459   659
# instagram                  172  477   649
# All                        372  936  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    2.3774
# 1                    p-value =    0.1231
# 2               Cramer's phi =    0.0426
#
# Importance: X
#
# [X83productposition_7]
#           X83productposition_7
#                              N    Y   All
# X1SNS
# Facebook                   219  440   659
# instagram                  196  453   649
# All                        415  893  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.3876
# 1                    p-value =    0.2388
# 2               Cramer's phi =    0.0326
#
# Importance: X
#
# [X83productposition_8]
#           X83productposition_8
#                              N     Y   All
# X1SNS
# Facebook                    46   613   659
# instagram                   48   601   649
# All                         94  1214  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0847
# 1                    p-value =    0.7710
# 2               Cramer's phi =    0.0080
#
# Importance: X
#
# [X83productposition_9]
#           X83productposition_9
#                              N    Y   All
# X1SNS
# Facebook                   189  470   659
# instagram                  182  467   649
# All                        371  937  1308
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0652
# 1                    p-value =    0.7984
# 2               Cramer's phi =    0.0071
#
# Importance: X

# %% [markdown]
# ### Camera Angle

# %%
angle = {1:'extreme high',2:'high',3:'eye',4:'low',5:'dutch',6:'other'}
chi_iter_sns(df_sns_clean,'X10angle',angle)
# Out:
# [dutch]
#           dutch
#               0  1   All
# X1SNS
# Facebook   1000  0  1000
# instagram   996  1   997
# All        1996  1  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    1.0035
# 1                    p-value =    0.3165
# 2               Cramer's phi =    0.0224
#
# Importance: X
#
# [extreme high]
#           extreme high
#                      0   1   All
# X1SNS
# Facebook           982  18  1000
# instagram          973  24   997
# All               1955  42  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.8941
# 1                    p-value =    0.3444
# 2               Cramer's phi =    0.0212
#
# Importance: X
#
# [eye]
#            eye
#              0     1   All
# X1SNS
# Facebook   259   741  1000
# instagram  250   747   997
# All        509  1488  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.1788
# 1                    p-value =    0.6724
# 2               Cramer's phi =    0.0095
#
# Importance: X
#
# [high]
#            high
#               0    1   All
# X1SNS
# Facebook    902   98  1000
# instagram   931   66   997
# All        1833  164  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    6.6982
# 1                    p-value =    0.0097
# 2               Cramer's phi =    0.0579
#
# Importance: **
#
# [low]
#             low
#               0    1   All
# X1SNS
# Facebook    869  131  1000
# instagram   851  146   997
# All        1720  277  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.9961
# 1                    p-value =    0.3182
# 2               Cramer's phi =    0.0223
#
# Importance: X
#
# [other]
#           other
#               0   1   All
# X1SNS
# Facebook    988  12  1000
# instagram   984  13   997
# All        1972  25  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =    0.0436
# 1                    p-value =    0.8346
# 2               Cramer's phi =    0.0047
#
# Importance: X

# %% [markdown]
# ### Hash Tag

# %%
col = 'X12hashtag'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X12hashtag]
#           X12hashtag
#                    N     Y   All
# X1SNS
# Facebook         753   247  1000
# instagram        239   758   997
# All              992  1005  1997
#
#                 Chi-square test   results
# 0  Pearson Chi-square ( 1.0) =   526.1452
# 1                    p-value =     0.0000
# 2               Cramer's phi =     0.5133
#
# Importance: ***

# %%
df_sns_clean['X12_2_5'].describe()
# Out:
# count    1997.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: X12_2_5, dtype: float64

# %%
df_hashtag = df_sns_clean[df_sns_clean['X12hashtag']==1]

# %%
print('[[Total]]\n')

ttest_col = ['X12_1number','X12_2_1content', 'X12_2_2', 'X12_2_3', 'X12_2_4', 'X12_2_6']


for col in ttest_col:
    print('[%s]'%col)
    result = t_test_sns(df_sns_clean,col)
    p = result[1].iloc[3,1]
    print(result[0],'\n')
    print(result[1],'\n')
    score = importance(p)
    print('Importance: %s\n'%score)
    
print('[[When Hashtag]]\n')

ttest_col = ['X12_1number','X12_2_1content', 'X12_2_2', 'X12_2_3', 'X12_2_4', 'X12_2_6']


for col in ttest_col:
    print('[%s]'%col)
    result = t_test_sns(df_hashtag,col)
    p = result[1].iloc[3,1]
    print(result[0],'\n')
    print(result[1],'\n')
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [[Total]]
#
# [X12_1number]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook  1000.0  0.292000  0.590834  0.018684   0.255336  0.328664
# 1  Instagram   997.0  1.348044  1.396434  0.044226   1.261258  1.434830
# 2   combined  1997.0  0.819229  1.194456  0.026729   0.766809  0.871648
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -1.0560
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =    -22.0193
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.9855
# 7                                     Hedge's g =     -0.9851
# 8                                 Glass's delta =     -1.7874
# 9                                             r =      0.4422
#
# Importance: ***
#
# [X12_2_1content]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook  1000.0  0.103000  0.323258  0.010222   0.082940  0.123060
# 1  Instagram   997.0  0.214644  0.413218  0.013087   0.188963  0.240325
# 2   combined  1997.0  0.158738  0.374995  0.008391   0.142281  0.175195
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.1116
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =     -6.7256
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.3010
# 7                                     Hedge's g =     -0.3009
# 8                                 Glass's delta =     -0.3454
# 9                                             r =      0.1489
#
# Importance: ***
#
# [X12_2_2]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook  1000.0  0.118000  0.340870  0.010779   0.096847  0.139153
# 1  Instagram   997.0  0.538616  1.042165  0.033006   0.473847  0.603385
# 2   combined  1997.0  0.327992  0.802727  0.017963   0.292764  0.363220
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.4206
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =    -12.1288
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.5428
# 7                                     Hedge's g =     -0.5426
# 8                                 Glass's delta =     -1.2339
# 9                                             r =      0.2621
#
# Importance: ***
#
# [X12_2_3]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook  1000.0  0.017000  0.129336  0.004090   0.008974  0.025026
# 1  Instagram   997.0  0.222668  0.521205  0.016507   0.190276  0.255060
# 2   combined  1997.0  0.119680  0.393074  0.008796   0.102429  0.136930
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.2057
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =    -12.1100
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.5420
# 7                                     Hedge's g =     -0.5418
# 8                                 Glass's delta =     -1.5902
# 9                                             r =      0.2617
#
# Importance: ***
#
# [X12_2_4]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook  1000.0  0.036000  0.186383  0.005894   0.024434  0.047566
# 1  Instagram   997.0  0.135406  0.351017  0.011117   0.113591  0.157221
# 2   combined  1997.0  0.085628  0.285204  0.006382   0.073112  0.098145
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.0994
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =     -7.9069
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.3539
# 7                                     Hedge's g =     -0.3537
# 8                                 Glass's delta =     -0.5333
# 9                                             r =      0.1743
#
# Importance: ***
#
# [X12_2_6]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook  1000.0  0.115000  0.397408  0.012567   0.090339  0.139661
# 1  Instagram   997.0  0.232698  0.609508  0.019303   0.194818  0.270578
# 2   combined  1997.0  0.173761  0.517579  0.011582   0.151046  0.196475
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.1177
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =     -5.1129
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.2288
# 7                                     Hedge's g =     -0.2287
# 8                                 Glass's delta =     -0.2962
# 9                                             r =      0.1137
#
# Importance: ***
#
# [[When Hashtag]]
#
# [X12_1number]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   247.0  1.182186  0.600818  0.038229   1.106888  1.257484
# 1  Instagram   758.0  1.773087  1.345756  0.048880   1.677131  1.869044
# 2   combined  1005.0  1.627861  1.232374  0.038874   1.551577  1.704144
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.5909
# 1                            Degrees of freedom =   1003.0000
# 2                                             t =     -6.6853
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.4898
# 7                                     Hedge's g =     -0.4894
# 8                                 Glass's delta =     -0.9835
# 9                                             r =      0.2065
#
# Importance: ***
#
# [X12_2_1content]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   247.0  0.417004  0.541184  0.034435   0.349180  0.484829
# 1  Instagram   758.0  0.282322  0.453350  0.016466   0.249997  0.314647
# 2   combined  1005.0  0.315423  0.479678  0.015131   0.285731  0.345115
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =      0.1347
# 1                            Degrees of freedom =   1003.0000
# 2                                             t =      3.8587
# 3                         Two side test p value =      0.0001
# 4  Mean of Facebook > mean of Instagram p value =      0.9999
# 5  Mean of Facebook < mean of Instagram p value =      0.0001
# 6                                     Cohen's d =      0.2827
# 7                                     Hedge's g =      0.2825
# 8                                 Glass's delta =      0.2489
# 9                                             r =      0.1209
#
# Importance: ***
#
# [X12_2_2]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   247.0  0.477733  0.547082  0.034810   0.409169  0.546296
# 1  Instagram   758.0  0.708443  1.143915  0.041549   0.626879  0.790008
# 2   combined  1005.0  0.651741  1.034326  0.032627   0.587717  0.715766
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.2307
# 1                            Degrees of freedom =   1003.0000
# 2                                             t =     -3.0571
# 3                         Two side test p value =      0.0023
# 4  Mean of Facebook > mean of Instagram p value =      0.0011
# 5  Mean of Facebook < mean of Instagram p value =      0.9989
# 6                                     Cohen's d =     -0.2240
# 7                                     Hedge's g =     -0.2238
# 8                                 Glass's delta =     -0.4217
# 9                                             r =      0.0961
#
# Importance: **
#
# [X12_2_3]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   247.0  0.068826  0.253672  0.016141   0.037034  0.100618
# 1  Instagram   758.0  0.292876  0.580372  0.021080   0.251494  0.334258
# 2   combined  1005.0  0.237811  0.528249  0.016663   0.205112  0.270509
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.2241
# 1                            Degrees of freedom =   1003.0000
# 2                                             t =     -5.8852
# 3                         Two side test p value =      0.0000
# 4  Mean of Facebook > mean of Instagram p value =      0.0000
# 5  Mean of Facebook < mean of Instagram p value =      1.0000
# 6                                     Cohen's d =     -0.4312
# 7                                     Hedge's g =     -0.4309
# 8                                 Glass's delta =     -0.8832
# 9                                             r =      0.1827
#
# Importance: ***
#
# [X12_2_4]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   247.0  0.145749  0.353571  0.022497   0.101437  0.190061
# 1  Instagram   758.0  0.178100  0.393065  0.014277   0.150074  0.206127
# 2   combined  1005.0  0.170149  0.383817  0.012107   0.146391  0.193907
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.0324
# 1                            Degrees of freedom =   1003.0000
# 2                                             t =     -1.1506
# 3                         Two side test p value =      0.2502
# 4  Mean of Facebook > mean of Instagram p value =      0.1251
# 5  Mean of Facebook < mean of Instagram p value =      0.8749
# 6                                     Cohen's d =     -0.0843
# 7                                     Hedge's g =     -0.0842
# 8                                 Glass's delta =     -0.0915
# 9                                             r =      0.0363
#
# Importance: X
#
# [X12_2_6]
#     Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0   Facebook   247.0  0.465587  0.690992  0.043967   0.378988  0.552186
# 1  Instagram   758.0  0.306069  0.682865  0.024803   0.257378  0.354759
# 2   combined  1005.0  0.345274  0.687966  0.021701   0.302689  0.387859
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =      0.1595
# 1                            Degrees of freedom =   1003.0000
# 2                                             t =      3.1791
# 3                         Two side test p value =      0.0015
# 4  Mean of Facebook > mean of Instagram p value =      0.9992
# 5  Mean of Facebook < mean of Instagram p value =      0.0008
# 6                                     Cohen's d =      0.2329
# 7                                     Hedge's g =      0.2327
# 8                                 Glass's delta =      0.2309
# 9                                             r =      0.0999
#
# Importance: **

# %% [markdown]
# ## Text

# %%
pd.DataFrame(df_sns_clean.isna().sum()).T
# Out:
#    BrandID  BrandCategory  PhotoID  PostURL  PhotoURL  PostDate  PostTime  \
# 0        0              0        0        0         3         0         0
#
#    DownloadDate  Type  type_video  Like  LikeAlbum  Comments  Comments_album  \
# 0             0     0           0     5       1836      1019            1841
#
#    NumHashtags  Content  ContentWithoutLink  X1SNS  X2brand  X3model  \
# 0            5       37                  40      0        0        0
#
#    X31number  X32face  X33body  X34modelposition  X4background  X5text  \
# 0        648      648      649               648             0       1
#
#    X51words   X52  X53textposition  X54promotingmessa  X6brandname  \
# 0      1722  1997             1722               1722            0
#
#    X61brandexpose   X62  X63brandposition  X64brandvisib  X65partofprod  \
# 0            1623  1997              1623           1623           1623
#
#    X66whproduct  X7logo  X71logoexposure   X72  X73logoposition  X74logotype  \
# 0          1747       0             1215  1996             1214         1214
#
#    X75logovisib  X76logopartofprod  X8product  X81productexpose   X82  \
# 0          1214               1213          0               236  1997
#
#    X83productposition    X9  X10angle   X11  X12hashtag  X12_1number  \
# 0                 236  1997         0  1997           0            0
#
#    X12_2_1content  X12_2_2  X12_2_3  X12_2_4  X12_2_5  X12_2_6  X13text  \
# 0               0        0        0        0        0        0        0
#
#    X13_1  X13_2promo  X13_2promo_wo_kor  X13_3link  XBrandCategory_SPA  \
# 0      0          42                 70         40                   0
#
#    XBrandCategory_casual  XBrandCategory_luxuries  XBrandCategory_sport  \
# 0                      0                        0                     0
#
#    X34modelposition_1  X34modelposition_2  X34modelposition_3  \
# 0                 648                 648                 648
#
#    X34modelposition_4  X34modelposition_5  X34modelposition_6  \
# 0                 648                 648                 648
#
#    X34modelposition_7  X34modelposition_8  X34modelposition_9  \
# 0                 648                 648                 648
#
#    X4background_indoor  X4background_others  X4background_outdoor  \
# 0                    0                    0                     0
#
#    X4background_wall  X53textposition_1  X53textposition_2  X53textposition_3  \
# 0                  0               1722               1722               1722
#
#    X53textposition_4  X53textposition_5  X53textposition_6  X53textposition_7  \
# 0               1722               1722               1722               1722
#
#    X53textposition_8  X53textposition_9  X63brandposition_1  \
# 0               1722               1722                1623
#
#    X63brandposition_2  X63brandposition_3  X63brandposition_4  \
# 0                1623                1623                1623
#
#    X63brandposition_5  X63brandposition_6  X63brandposition_7  \
# 0                1623                1623                1623
#
#    X63brandposition_8  X63brandposition_9  X66whproduct_accessories  \
# 0                1623                1623                      1747
#
#    X66whproduct_bag  X66whproduct_clothes_bottom  X66whproduct_clothes_top  \
# 0              1747                         1747                      1747
#
#    X66whproduct_cosmetics  X66whproduct_hat  X66whproduct_others  \
# 0                    1747              1747                 1747
#
#    X66whproduct_shoes  X73logoposition_1  X73logoposition_2  \
# 0                1747               1214               1214
#
#    X73logoposition_3  X73logoposition_4  X73logoposition_5  X73logoposition_6  \
# 0               1214               1214               1214               1214
#
#    X73logoposition_7  X73logoposition_8  X73logoposition_9  X74logotype_both  \
# 0               1214               1214               1214              1214
#
#    X74logotype_image  X74logotype_text  X83productposition_1  \
# 0               1214              1214                   236
#
#    X83productposition_2  X83productposition_3  X83productposition_4  \
# 0                   236                   236                   236
#
#    X83productposition_5  X83productposition_6  X83productposition_7  \
# 0                   236                   236                   236
#
#    X83productposition_8  X83productposition_9  X10angle_extreme_high  \
# 0                   236                   236                      0
#
#    X10angle_eye  X10angle_high  X10angle_low  X10angle_other
# 0             0              0             0               0

# %%
len(df_sns_clean['ContentWithoutLink'][0])
# Out:
# 158

# %%
col = 'X13text'

result = chi_sns(df_sns_clean,col)
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X13text]
#           X13text
#                 N     Y   All
# X1SNS
# Facebook       42   958  1000
# instagram       0   997   997
# All            42  1955  1997
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   42.7736
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.1464
#
# Importance: ***

# %%
ttest_col = ['X13_1']


for col in ttest_col:
    print('[%s]'%col)
    result = t_test_sns(df_sns_clean,col)
    p = result[1].iloc[3,1]
    print(result[0],'\n')
    print(result[1],'\n')
    score = importance(p)
    print('Importance: %s\n'%score)
# Out:
# [X13_1]
#     Variable       N       Mean         SD        SE  95% Conf.   Interval
# 0   Facebook  1000.0  21.880000  19.088792  0.603641  20.695451  23.064549
# 1  Instagram   997.0  22.413240  15.554405  0.492613  21.446561  23.379918
# 2   combined  1997.0  22.146219  17.411835  0.389633  21.382090  22.910349
#
#                                 Independent t-test    results
# 0             Difference (Facebook - Instagram) =     -0.5332
# 1                            Degrees of freedom =   1995.0000
# 2                                             t =     -0.6842
# 3                         Two side test p value =      0.4939
# 4  Mean of Facebook > mean of Instagram p value =      0.2470
# 5  Mean of Facebook < mean of Instagram p value =      0.7530
# 6                                     Cohen's d =     -0.0306
# 7                                     Hedge's g =     -0.0306
# 8                                 Glass's delta =     -0.0279
# 9                                             r =      0.0153
#
# Importance: X

# %%
df_posting = df_sns_clean[(df_sns_clean['X13text']==1)&(df_sns_clean['X13_2promo']!=3)]
result = chi_sns(df_posting,'X13_2promo')
p = result[1].iloc[1,1]
score = importance(p)

print('[%s]'%col)
print(result[0],'\n')
print(result[1],'\n')
print('Importance: %s\n'%score)
# Out:
# [X13_1]
#           X13_2promo
#                  2.0    Y   All
# X1SNS
# Facebook         532  398   930
# instagram        422  575   997
# All              954  973  1927
#
#                 Chi-square test  results
# 0  Pearson Chi-square ( 1.0) =   42.6038
# 1                    p-value =    0.0000
# 2               Cramer's phi =    0.1487
#
# Importance: ***
